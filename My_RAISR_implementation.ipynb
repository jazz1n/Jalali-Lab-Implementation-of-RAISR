# %% [markdown]
# <a href="https://colab.research.google.com/github/jazz1n/Jalali-Lab-Implementation-of-RAISR/blob/master/My_RAISR_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jazz1n/Jalali-Lab-Implementation-of-RAISR
# Out:
# Cloning into 'Jalali-Lab-Implementation-of-RAISR'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 272 (delta 16), reused 25 (delta 8), pack-reused 237
# Receiving objects: 100% (272/272), 28.35 MiB | 36.29 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd Jalali-Lab-Implementation-of-RAISR
# Out:
# /content/Jalali-Lab-Implementation-of-RAISR

# %%
# !python Train.py
# Out:
#  Quantization: Processing 10000000.0 patches (0.0%)
#  Quantization: Processing 10000000.0 patches (1.457%)
#  Quantization: Processing 10000000.0 patches (2.914%)
#  Quantization: Processing 10000000.0 patches (4.371%)
#  Quantization: Processing 10000000.0 patches (5.828%)
#  Quantization: Processing 10000000.0 patches (7.285%)
#  Quantization: Processing 10000000.0 patches (8.742%)
#  Quantization: Processing 10000000.0 patches (10.199%)
#  Quantization: Processing 10000000.0 patches (11.656%)
#  Quantization: Processing 10000000.0 patches (13.113%)
#  Quantization: Processing 10000000.0 patches (14.57%)
#  Quantization: Processing 10000000.0 patches (16.027%)
#  Quantization: Processing 10000000.0 patches (17.484%)
#  Quantization: Processing 10000000.0 patches (18.941%)
#  Quantization: Processing 10000000.0 patches (20.398%)
#  Quantization: Processing 10000000.0 patches (21.855%)
#  Quantization: Processing 10000000.0 patches (23.312%)
# ...

# %%
# !python Test.py
# Out:
# Begin to process images:
#  Processing 1/5 image (testData/img_001_SRF_2_HR.png)
# 6.3804426193237305
#  Processing 2/5 image (testData/img_003_SRF_2_HR.png)
# 2.5273075103759766
#  Processing 3/5 image (testData/img_002_SRF_2_HR.png)
# 2.740102529525757
#  Processing 4/5 image (testData/img_005_SRF_2_HR.png)
# 3.3517401218414307
#  Processing 5/5 image (testData/img_004_SRF_2_HR.png)
# 2.737135410308838
#  RAISR PSNR of testData is 35.54336641750483
#  Bicubic PSNR of testData is 34.36810087773047
